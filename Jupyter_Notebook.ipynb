# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# **Eran Dodampe Gamage** <br>
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because I enjoy working with Data and using them to prediction and forecasting using machine leaining models.*

# %% [markdown]
# <h3>Addition<h3>

# %%
x = 2
y = 5
print(x+y)
# Out:
# 7

# %% [markdown]
# - horizontal rule
# - numbered list
# - tables
# - hyperlinks
# - images
# - code/syntax highlighting
# - blocked quotes
# - strikethrough
